# %%
from model_validator import *

# %%
train_and_validate('u23_1_training_data.csv','u23_1_test_data.csv')
# Out:
# 53
# PAGE: i:0 http://www.standaard.be/cnt/dmf20160325_02204284
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-c40716e72806> in <module>()
# ----> 1 train_and_validate('u23_1_training_data.csv','u23_1_test_data.csv')
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/model_validator.py in train_and_validate(csv_file_training, csv_file_validate)
#      15         # Returns a dictionary with the number of primary, secondary and tertiary
#      16         #       predictions that were correct
# ---> 17         validation = validate(pages)
#      18
#      19         return validation
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/model_validator.py in validate(pages)
#      36
#      37                 print("PAGE: " + "i:" + str(i) + " " + page)
# ---> 38                 predictions = pred.get_guesses(page)
#      39
#      40                 j = 0
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/url_predictor.py in get_guesses(url_1)
#     263     destination pages. """
#     264     # Get the metadata of the page at url_1.
# --> 265     P1 = nodes[url_1]
#     266
#     267     # All node metadata.
#
# KeyError: 'http://www.standaard.be/cnt/dmf20160325_02204284'

# %%
train_and_validate('u23_1_training_data.csv','u23_1_test_data.csv')
# Out:
# 53
# PAGE: i:0 http://www.standaard.be/cnt/dmf20160325_02204284
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   4.076
# Bayes p: 0.006373
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   1.145
# Bayes p: 0.004091
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   1.885
# Bayes p: 0.000375
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/
#
# PAGE: i:1 http://www.standaard.be/plus
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   4.041
# Bayes p: 0.006319
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   1.164
# Bayes p: 0.004160
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   1.910
# Bayes p: 0.000380
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/
#
# PAGE: i:2 http://www.standaard.be/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   1.173
# Bayes p: 0.004194
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   1.908
# Bayes p: 0.000380
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.833   0.923   0.022   0.020   0.000   0.761
# Bayes p: 0.000344
#
#
# 	 WEB PAGE: 2: http://www.standaard.be/nieuws/binnenland
#
# PAGE: i:3 http://www.standaard.be/nieuws/binnenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   2.884
# Bayes p: 0.004510
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   1.180
# Bayes p: 0.004218
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.833   0.923   0.022   0.020   0.000   0.449
# Bayes p: 0.000203
#
#
# 	 WEB PAGE: 3: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:4 http://www.standaard.be/cnt/dmf20160326_02205525
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   3.846
# Bayes p: 0.006014
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   1.219
# Bayes p: 0.004356
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   1.763
# Bayes p: 0.000351
#
#
# PAGE: i:5 http://www.standaard.be/tag/aanslagen-brussel
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   1.646
# Bayes p: 0.005882
#
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   3.153
# Bayes p: 0.004930
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   1.336
# Bayes p: 0.000266
#
#
# PAGE: i:6 http://www.standaard.be/nieuws/buitenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   0.726
# Bayes p: 0.001135
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   0.271
# Bayes p: 0.000968
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   2.303
# Bayes p: 0.000458
#
#
# PAGE: i:7 http://www.standaard.be/plus/krant/opinie/opinies
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   0.650
# Bayes p: 0.001017
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   0.158
# Bayes p: 0.000565
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   1.797
# Bayes p: 0.000358
#
#
# PAGE: i:8 http://www.standaard.be/nieuws/buitenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   0.726
# Bayes p: 0.001135
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   0.271
# Bayes p: 0.000968
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   2.303
# Bayes p: 0.000458
#
#
# PAGE: i:9 http://www.standaard.be/nieuws/sport
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   1.488
# Bayes p: 0.002327
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   0.516
# Bayes p: 0.001845
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   2.491
# Bayes p: 0.000496
#
#
# PAGE: i:10 http://www.standaard.be/nieuws/sport/voetbal
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   1.603
# Bayes p: 0.002507
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   0.631
# Bayes p: 0.002256
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   2.697
# Bayes p: 0.000537
#
#
# PAGE: i:11 http://www.standaard.be/nieuws/sport/voetbal?page=2
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   1.854
# Bayes p: 0.002899
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   0.721
# Bayes p: 0.002576
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   2.556
# Bayes p: 0.000509
#
#
# PAGE: i:12 http://www.standaard.be/cnt/dmf20160325_02203505
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   1.943
# Bayes p: 0.003039
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   0.807
# Bayes p: 0.002884
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   2.667
# Bayes p: 0.000531
#
#
# PAGE: i:13 http://www.standaard.be/plus/ochtend
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   2.115
# Bayes p: 0.003308
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   0.859
# Bayes p: 0.003069
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   2.539
# Bayes p: 0.000505
#
#
# PAGE: i:14 http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F4
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   1.943
# Bayes p: 0.003039
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   0.807
# Bayes p: 0.002884
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   2.667
# Bayes p: 0.000531
#
#
# PAGE: i:15 http://www.standaard.be/plus/ochtend
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   2.115
# Bayes p: 0.003308
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   0.859
# Bayes p: 0.003069
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.833   0.406   0.022   0.009   1.000   2.539
# Bayes p: 0.000505
#
#
# PAGE: i:16 http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F30
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   1.000   1.193
# Bayes p: 0.001865
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.833   0.923   0.022   0.020   0.000   2.519
# Bayes p: 0.001138
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   1.000   0.216
# Bayes p: 0.000771
#
#
# 	 WEB PAGE: 2: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:17 https://search.yahoo.com/yhs/search?p=deredactie&ei=UTF-8&hspart=mozilla&hsimp=yhs-002
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   0.000   1.305
# Bayes p: 0.002041
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.833   0.923   0.022   0.020   0.000   2.449
# Bayes p: 0.001106
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   0.000   0.254
# Bayes p: 0.000908
#
#
# 	 WEB PAGE: 2: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:18 http://deredactie.be/cm/vrtnieuws
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   0.000   1.370
# Bayes p: 0.002141
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.833   0.923   0.022   0.020   1.000   2.441
# Bayes p: 0.001103
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   0.000   0.286
# Bayes p: 0.001021
#
#
# 	 WEB PAGE: 2: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:19 http://deredactie.be/cm/vrtnieuws/videozone
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   0.000   1.486
# Bayes p: 0.002324
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   0.000   0.325
# Bayes p: 0.001163
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.833   0.923   0.022   0.020   1.000   2.336
# Bayes p: 0.001055
#
#
# 	 WEB PAGE: 3: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:20 http://deredactie.be/cm/vrtnieuws/videozone/nieuws/politiek/1.2612587
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   0.000   0.921
# Bayes p: 0.001439
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   0.000   0.197
# Bayes p: 0.000703
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.833   0.923   0.022   0.020   1.000   1.524
# Bayes p: 0.000689
#
#
# 	 WEB PAGE: 3: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:21 http://deredactie.be/cm/vrtnieuws/2.43497/1.2612632?playlist=7.39637
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   0.000   1.711
# Bayes p: 0.002675
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   0.000   0.367
# Bayes p: 0.001311
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.833   0.923   0.022   0.020   1.000   2.796
# Bayes p: 0.001263
#
#
# 	 WEB PAGE: 3: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:22 http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal/2.43555?video=1.2612481
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   0.000   1.741
# Bayes p: 0.002723
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   0.000   0.398
# Bayes p: 0.001422
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.833   0.923   0.022   0.020   1.000   2.739
# Bayes p: 0.001238
#
#
# 	 WEB PAGE: 3: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:23 http://deredactie.be/cm/vrtnieuws/videozone/nieuws/binnenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   0.000   1.883
# Bayes p: 0.002944
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   0.000   0.435
# Bayes p: 0.001553
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.833   0.923   0.022   0.020   1.000   2.582
# Bayes p: 0.001167
#
#
# 	 WEB PAGE: 3: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:24 http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   0.000   1.907
# Bayes p: 0.002982
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   0.000   0.485
# Bayes p: 0.001733
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    1.947   0.743   0.015   0.011   1.000   1.426
# Bayes p: 0.000245
#
#
# 	 WEB PAGE: 3: http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
# PAGE: i:25 http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.488   0.851   0.043   0.036   0.000   0.792
# Bayes p: 0.001238
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.770  18.683   0.014   0.258   0.000   0.181
# Bayes p: 0.000646
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.833   0.923   0.022   0.020   1.000   1.245
# Bayes p: 0.000563
#
#
# PAGE: i:26 http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal/2.43555?video=1.2612492
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   0.000   1.416
# Bayes p: 0.000028
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   0.000   1.367
# Bayes p: 0.000028
#
#
# https://search.yahoo.com/yhs/search?p=kuleuven+ingenieurswetenschappen&ei=UTF-8&hspart=mozilla&hsimp=yhs-002
#
#    1.770   0.062   0.014   0.001   0.000   1.464
# Bayes p: 0.000017
#
#
# 	 WEB PAGE: 2: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:27 http://deredactie.be/cm/vrtnieuws/videozone/nieuws
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   0.000   1.439
# Bayes p: 0.000028
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   0.000   1.389
# Bayes p: 0.000028
#
#
# https://search.yahoo.com/yhs/search?p=kuleuven+ingenieurswetenschappen&ei=UTF-8&hspart=mozilla&hsimp=yhs-002
#
#    1.770   0.062   0.014   0.001   0.000   1.331
# Bayes p: 0.000016
#
#
# 	 WEB PAGE: 2: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:28 http://deredactie.be/cm/vrtnieuws/videozone/livestream
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   0.000   1.460
# Bayes p: 0.000029
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   0.000   1.262
# Bayes p: 0.000026
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01
#
#    1.770   0.091   0.014   0.001   0.000   0.822
# Bayes p: 0.000014
#
#
# 	 WEB PAGE: 2: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:29 http://www.kuleuven.be/studenten/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   3.716
# Bayes p: 0.000075
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.079
# Bayes p: 0.000021
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/CQ_50268945.htm
#
#    1.770   0.044   0.014   0.001   1.000   1.962
# Bayes p: 0.000017
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:30 http://www.kuleuven.be/studenten/starters/index.html
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   3.378
# Bayes p: 0.000068
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   2.060
# Bayes p: 0.000041
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/CQ_50268945.htm
#
#    1.770   0.044   0.014   0.001   1.000   2.323
# Bayes p: 0.000020
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:31 http://nieuws.kuleuven.be/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   3.287
# Bayes p: 0.000067
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   2.142
# Bayes p: 0.000042
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01
#
#    1.770   0.091   0.014   0.001   1.000   1.030
# Bayes p: 0.000018
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:32 http://nieuws.kuleuven.be/taxonomy/term/59
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.988
# Bayes p: 0.000060
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   2.217
# Bayes p: 0.000044
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01
#
#    1.770   0.091   0.014   0.001   1.000   1.071
# Bayes p: 0.000019
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:33 http://www.kuleuven.be/kuleuven/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.770
# Bayes p: 0.000056
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   2.083
# Bayes p: 0.000041
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01
#
#    1.770   0.091   0.014   0.001   1.000   1.243
# Bayes p: 0.000022
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:34 http://www.kuleuven.be/studeren/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.519
# Bayes p: 0.000051
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.961
# Bayes p: 0.000039
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01
#
#    1.770   0.091   0.014   0.001   1.000   1.299
# Bayes p: 0.000023
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:35 https://onderwijsaanbod.kuleuven.be/opleidingen/n/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.611
# Bayes p: 0.000053
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.800
# Bayes p: 0.000035
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.656   0.115   0.021   0.002   1.000   0.515
# Bayes p: 0.000025
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:36 https://onderwijsaanbod.kuleuven.be/opleidingen/n/#bl=9;&f=-1,-1,-1,-1
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.374
# Bayes p: 0.000048
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.656   0.115   0.021   0.002   1.000   0.738
# Bayes p: 0.000036
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.653
# Bayes p: 0.000033
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:37 https://onderwijsaanbod.kuleuven.be/opleidingen/n/#bl=9;-1&f=-1,-1,-1,-1
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.656   0.115   0.021   0.002   1.000   1.008
# Bayes p: 0.000050
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.360
# Bayes p: 0.000048
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.603
# Bayes p: 0.000032
#
#
# 	 WEB PAGE: 2: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:38 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.656   0.115   0.021   0.002   1.000   1.163
# Bayes p: 0.000057
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.145
# Bayes p: 0.000043
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.558
# Bayes p: 0.000031
#
#
# 	 WEB PAGE: 2: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:39 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.656   0.115   0.021   0.002   1.000   1.288
# Bayes p: 0.000064
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.479
# Bayes p: 0.000029
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm#activetab=doelstellingen_idm2097504
#
#    1.770   0.162   0.014   0.002   1.000   0.715
# Bayes p: 0.000022
#
#
# PAGE: i:40 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.656   0.115   0.021   0.002   1.000   1.163
# Bayes p: 0.000057
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.145
# Bayes p: 0.000043
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.558
# Bayes p: 0.000031
#
#
# 	 WEB PAGE: 2: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:41 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.656   0.115   0.021   0.002   1.000   1.288
# Bayes p: 0.000064
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.479
# Bayes p: 0.000029
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm#activetab=doelstellingen_idm2097504
#
#    1.770   0.162   0.014   0.002   1.000   0.715
# Bayes p: 0.000022
#
#
# PAGE: i:42 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.656   0.115   0.021   0.002   1.000   1.163
# Bayes p: 0.000057
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.145
# Bayes p: 0.000043
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.558
# Bayes p: 0.000031
#
#
# 	 WEB PAGE: 2: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:43 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.656   0.115   0.021   0.002   1.000   1.288
# Bayes p: 0.000064
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.479
# Bayes p: 0.000029
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm#activetab=doelstellingen_idm2097504
#
#    1.770   0.162   0.014   0.002   1.000   0.715
# Bayes p: 0.000022
#
#
# PAGE: i:44 http://www.kuleuven.be/wieiswie/nl/person
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.525
# Bayes p: 0.000051
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.794
# Bayes p: 0.000035
#
#
# https://eng.kuleuven.be/studenten
#
#    1.062   0.131   0.008   0.001   1.000   1.744
# Bayes p: 0.000016
#
#
# 	 WEB PAGE: 3: https://eng.kuleuven.be/studenten
#
# PAGE: i:45 https://eng.kuleuven.be/toekomstigestudenten
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.376
# Bayes p: 0.000048
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.722
# Bayes p: 0.000034
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01
#
#    1.770   0.091   0.014   0.001   1.000   0.993
# Bayes p: 0.000017
#
#
# PAGE: i:46 https://eng.kuleuven.be/toekomstigestudenten/burgerlijk-ingenieur
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.160
# Bayes p: 0.000044
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.657
# Bayes p: 0.000033
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01
#
#    1.770   0.091   0.014   0.001   1.000   1.045
# Bayes p: 0.000018
#
#
# PAGE: i:47 https://eng.kuleuven.be/studenten
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.205
# Bayes p: 0.000045
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.531
# Bayes p: 0.000030
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01
#
#    1.770   0.091   0.014   0.001   1.000   1.058
# Bayes p: 0.000018
#
#
# PAGE: i:48 https://eng.kuleuven.be/studenten/programmas/index.html
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.004
# Bayes p: 0.000041
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.417
# Bayes p: 0.000028
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.656   0.115   0.021   0.002   1.000   0.555
# Bayes p: 0.000027
#
#
# PAGE: i:49 https://eng.kuleuven.be/webcms/Shibboleth.sso/Login?target=https://eng.kuleuven.be/archief-hoofdpagina/recover/studenten/deadlines-2014-2015.pdf
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.205
# Bayes p: 0.000045
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.531
# Bayes p: 0.000030
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01
#
#    1.770   0.091   0.014   0.001   1.000   1.058
# Bayes p: 0.000018
#
#
# PAGE: i:50 https://eng.kuleuven.be/studenten/programmas/index.html
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.416   0.165   0.011   0.002   1.000   2.004
# Bayes p: 0.000041
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.770   0.103   0.014   0.001   1.000   1.417
# Bayes p: 0.000028
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.656   0.115   0.021   0.002   1.000   0.555
# Bayes p: 0.000027
#
#
# PAGE: i:51 https://eng.kuleuven.be/english/education/internationalisation
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://eng.kuleuven.be/english/education/internationalisation/Erasmus/exchange
#
#    0.177   0.099   0.001   0.000   1.000   1.210
# Bayes p: 0.000000
# ({'1': 10, '2': 11, '3': 8}, 5.4482758620689653)

# %%
preprocess('u23_1_test_data.csv')
# Out:
# ['http://www.standaard.be/cnt/dmf20160325_02204284',
#  'http://www.standaard.be/plus',
#  'http://www.standaard.be/',
#  'http://www.standaard.be/nieuws/binnenland',
#  'http://www.standaard.be/cnt/dmf20160326_02205525',
#  'http://www.standaard.be/tag/aanslagen-brussel',
#  'http://www.standaard.be/nieuws/buitenland',
#  'http://www.standaard.be/plus/krant/opinie/opinies',
#  'http://www.standaard.be/nieuws/buitenland',
#  'http://www.standaard.be/nieuws/sport',
#  'http://www.standaard.be/nieuws/sport/voetbal',
#  'http://www.standaard.be/nieuws/sport/voetbal?page=2',
#  'http://www.standaard.be/cnt/dmf20160325_02203505',
#  'http://www.standaard.be/plus/ochtend',
#  'http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F4',
#  'http://www.standaard.be/plus/ochtend',
#  'http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F30',
#  'https://search.yahoo.com/yhs/search?p=deredactie&ei=UTF-8&hspart=mozilla&hsimp=yhs-002',
#  'http://deredactie.be/cm/vrtnieuws',
#  'http://deredactie.be/cm/vrtnieuws/videozone',
#  'http://deredactie.be/cm/vrtnieuws/videozone/nieuws/politiek/1.2612587',
#  'http://deredactie.be/cm/vrtnieuws/2.43497/1.2612632?playlist=7.39637',
#  'http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal/2.43555?video=1.2612481',
#  'http://deredactie.be/cm/vrtnieuws/videozone/nieuws/binnenland',
#  'http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal',
#  'http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken',
#  'http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal/2.43555?video=1.2612492',
#  'http://deredactie.be/cm/vrtnieuws/videozone/nieuws',
#  'http://deredactie.be/cm/vrtnieuws/videozone/livestream',
#  'http://www.kuleuven.be/studenten/',
#  'http://www.kuleuven.be/studenten/starters/index.html',
#  'http://nieuws.kuleuven.be/',
#  'http://nieuws.kuleuven.be/taxonomy/term/59',
#  'http://www.kuleuven.be/kuleuven/',
#  'http://www.kuleuven.be/studeren/',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/#bl=9;&f=-1,-1,-1,-1',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/#bl=9;-1&f=-1,-1,-1,-1',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all',
#  'http://www.kuleuven.be/wieiswie/nl/person',
#  'https://eng.kuleuven.be/toekomstigestudenten',
#  'https://eng.kuleuven.be/toekomstigestudenten/burgerlijk-ingenieur',
#  'https://eng.kuleuven.be/studenten',
#  'https://eng.kuleuven.be/studenten/programmas/index.html',
#  'https://eng.kuleuven.be/webcms/Shibboleth.sso/Login?target=https://eng.kuleuven.be/archief-hoofdpagina/recover/studenten/deadlines-2014-2015.pdf',
#  'https://eng.kuleuven.be/studenten/programmas/index.html',
#  'https://eng.kuleuven.be/english/education/internationalisation',
#  'https://eng.kuleuven.be/english/education/internationalisation/Erasmus/exchange']

# %%
0 != 0.000
# Out:
# False

# %%
round(6.309999,2)
# Out:
# 6.31
