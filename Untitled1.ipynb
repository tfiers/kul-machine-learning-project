# %%
1+1
# Out:
# 2

# %%
ls
# Out:
# KUL_README                      requirements.txt
# Literature/                     research.bib
# README.md                       research.log
# Report/                         u23_1.csv
# Time management sheet link.rtf  u23_1_test_data.csv
# Untitled.ipynb                  u23_1_training_data.csv
# Untitled1.ipynb                 urlStreamHandler.py
# __pycache__/                    urlStreamHandler.user.js
# model_validator.py              url_predictor.py
# model_validator.pyc             url_predictor.pyc

# %%
from model_validator import *

# %%
pages = preprocess("u23_1_test_data.csv")

# %%
validate(pages)
# Out:
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# ...

# %%
train_model("u23_1_training_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-088012a2b9ce> in <module>()
# ----> 1 train_model("u23_1_training_data.csv")
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/model_validator.py in train_model(filename)
#      21 	"""
#      22         with open(filename, 'r') as csv_file:
# ---> 23                 pred.handle_csv(csv_file)
#      24
#      25         print("test")
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/url_predictor.py in handle_csv(csv_file_handle)
#      38     The model is stored in the global variable 'model').
#      39     """
# ---> 40     preprocessed_data = preprocess(csv_file_handle)
#      41     learn(preprocessed_data)
#      42
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/url_predictor.py in preprocess(csv_file_handle)
#     145     """
# ...
