# %%
from model_validator import *

# %%
os.path.join('data', 'u23_1.csv')
# Out:
# 'data/u23_1.csv'

# %%
validate_user(['data/u22_1.csv'])
# Out:
# 0.703125
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-c0b38fe1721f> in <module>()
# ----> 1 validate_user(['data/u22_1.csv'])
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/model_validator.py in validate_user(user_files)
#     108                         pred.learn_from(open(file),1)
#     109                 elif fraction > 0:
# --> 110                         pred.learn_from(open(file),fraction)
#     111                         pages = preprocess(file,fraction)
#     112                         result = validate(pages)
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/url_predictor.py in learn_from(csv_file_handle, fraction)
#      56     events = parse(lines)
#      57     # Make a list of 'page visit' dictionaries.
# ---> 58     page_visits = make_page_visits(events)
#      59     # Calculate the number of page visits that should be trained on.
#      60     n = int(round(fraction*len(page_visits)))
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/url_predictor.py in make_page_visits(events)
#     102         curent_event = events[i]
#     103         if curent_event['event_type'] in start_events:
# --> 104             next_event = events[i+1]
#     105             # Determine the amount of time the user stayed on this
#     106             # page.
#
# IndexError: list index out of range

# %%
train_and_validate('u23_1.csv','u23_1_test_data.csv')
# Out:
# 53
# PAGE: i:0 http://www.standaard.be/cnt/dmf20160325_02204284
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   1.000   0.164
# Bayes p: 0.006128
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.076
# Bayes p: 0.001624
#
#
# http://www.standaard.be/plus/ochtend
#
#    2.738   1.000   0.021   1.000   1.000   0.038
# Bayes p: 0.000809
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/
#
# PAGE: i:1 http://www.standaard.be/plus
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   1.000   0.169
# Bayes p: 0.006341
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.080
# Bayes p: 0.001703
#
#
# http://www.standaard.be/plus/ochtend
#
#    2.738   1.000   0.021   1.000   1.000   0.042
# Bayes p: 0.000900
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/
#
# PAGE: i:2 http://www.standaard.be/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.083
# Bayes p: 0.001778
#
#
# http://www.standaard.be/plus/ochtend
#
#    2.738   1.000   0.021   1.000   1.000   0.048
# Bayes p: 0.001018
#
#
# http://www.standaard.be/tag/aanslagen-brussel
#
#    2.053   1.000   0.016   1.000   1.000   0.058
# Bayes p: 0.000926
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/nieuws/binnenland
#
# PAGE: i:3 http://www.standaard.be/nieuws/binnenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   1.000   0.079
# Bayes p: 0.002939
#
#
# http://www.standaard.be/plus/ochtend
#
#    2.738   1.000   0.021   1.000   1.000   0.082
# Bayes p: 0.001762
#
#
# http://www.standaard.be/tag/aanslagen-brussel
#
#    2.053   1.000   0.016   1.000   1.000   0.080
# Bayes p: 0.001276
#
#
# 	 WEB PAGE: 2: http://www.standaard.be/plus/ochtend
#
# PAGE: i:4 http://www.standaard.be/cnt/dmf20160326_02205525
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   1.000   0.115
# Bayes p: 0.004303
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.056
# Bayes p: 0.001201
#
#
# http://www.standaard.be/tag/aanslagen-brussel
#
#    2.053   1.000   0.016   1.000   1.000   0.085
# Bayes p: 0.001365
#
#
# 	 WEB PAGE: 3: http://www.standaard.be/tag/aanslagen-brussel
#
# PAGE: i:5 http://www.standaard.be/tag/aanslagen-brussel
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   1.000   0.078
# Bayes p: 0.002921
#
#
# http://www.standaard.be/plus/ochtend
#
#    2.738   1.000   0.021   1.000   1.000   0.065
# Bayes p: 0.001391
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.042
# Bayes p: 0.000894
#
#
# 	 WEB PAGE: 2: http://www.standaard.be/plus/ochtend
#
# PAGE: i:6 http://www.standaard.be/nieuws/buitenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.738   1.000   0.021   1.000   1.000   0.147
# Bayes p: 0.003139
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.040
# Bayes p: 0.000858
#
#
# http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F4
#
#    1.369   1.000   0.011   1.000   1.000   0.073
# Bayes p: 0.000784
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:7 http://www.standaard.be/plus/krant/opinie/opinies
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.738   1.000   0.021   1.000   1.000   0.147
# Bayes p: 0.003137
#
#
# http://www.standaard.be/nieuws/buitenland
#
#    1.369   0.968   0.011   0.999   1.000   0.169
# Bayes p: 0.001801
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.032
# Bayes p: 0.000684
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:8 http://www.standaard.be/nieuws/buitenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.738   1.000   0.021   1.000   1.000   0.147
# Bayes p: 0.003139
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.040
# Bayes p: 0.000858
#
#
# http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F4
#
#    1.369   1.000   0.011   1.000   1.000   0.073
# Bayes p: 0.000784
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:9 http://www.standaard.be/nieuws/sport
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.738   1.000   0.021   1.000   1.000   0.182
# Bayes p: 0.003901
#
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   1.000   0.022
# Bayes p: 0.000811
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.050
# Bayes p: 0.001070
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:10 http://www.standaard.be/nieuws/sport/voetbal
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.738   1.000   0.021   1.000   1.000   0.184
# Bayes p: 0.003929
#
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   1.000   0.025
# Bayes p: 0.000940
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.055
# Bayes p: 0.001174
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:11 http://www.standaard.be/nieuws/sport/voetbal?page=2
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.738   1.000   0.021   1.000   1.000   0.191
# Bayes p: 0.004083
#
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   1.000   0.030
# Bayes p: 0.001123
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.057
# Bayes p: 0.001212
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:12 http://www.standaard.be/cnt/dmf20160325_02203505
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.738   1.000   0.021   1.000   1.000   0.193
# Bayes p: 0.004127
#
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   1.000   0.034
# Bayes p: 0.001277
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.061
# Bayes p: 0.001296
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:13 http://www.standaard.be/plus/ochtend
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   1.000   0.039
# Bayes p: 0.001441
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.063
# Bayes p: 0.001345
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.738   1.000   0.021   1.000   0.000   0.038
# Bayes p: 0.000815
#
#
# 	 WEB PAGE: 3: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:14 http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F4
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.738   1.000   0.021   1.000   1.000   0.193
# Bayes p: 0.004127
#
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   1.000   0.034
# Bayes p: 0.001277
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.061
# Bayes p: 0.001296
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:15 http://www.standaard.be/plus/ochtend
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   1.000   0.039
# Bayes p: 0.001441
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   1.000   0.063
# Bayes p: 0.001345
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.738   1.000   0.021   1.000   0.000   0.038
# Bayes p: 0.000815
#
#
# 	 WEB PAGE: 3: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:16 http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F30
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.738   1.000   0.021   1.000   0.000   0.090
# Bayes p: 0.001927
#
#
# http://deredactie.be/cm/vrtnieuws/videozone
#
#    2.053   1.000   0.016   1.000   0.000   0.085
# Bayes p: 0.001368
#
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   1.000   0.026
# Bayes p: 0.000959
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:17 https://search.yahoo.com/yhs/search?p=deredactie&ei=UTF-8&hspart=mozilla&hsimp=yhs-002
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.738   1.000   0.021   1.000   0.000   0.092
# Bayes p: 0.001973
#
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   0.000   0.030
# Bayes p: 0.001116
#
#
# http://deredactie.be/cm/vrtnieuws/videozone
#
#    2.053   1.000   0.016   1.000   0.000   0.086
# Bayes p: 0.001381
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:18 http://deredactie.be/cm/vrtnieuws
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.738   1.000   0.021   1.000   1.000   0.096
# Bayes p: 0.002057
#
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   0.000   0.033
# Bayes p: 0.001241
#
#
# http://deredactie.be/cm/vrtnieuws/videozone
#
#    2.053   1.000   0.016   1.000   1.000   0.087
# Bayes p: 0.001392
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:19 http://deredactie.be/cm/vrtnieuws/videozone
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.738   1.000   0.021   1.000   1.000   0.101
# Bayes p: 0.002164
#
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   0.000   0.037
# Bayes p: 0.001378
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    2.053   1.000   0.016   1.000   1.000   0.075
# Bayes p: 0.001200
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:20 http://deredactie.be/cm/vrtnieuws/videozone/nieuws/politiek/1.2612587
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.738   1.000   0.021   1.000   1.000   0.078
# Bayes p: 0.001668
#
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   0.000   0.028
# Bayes p: 0.001067
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    2.053   1.000   0.016   1.000   1.000   0.084
# Bayes p: 0.001345
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:21 http://deredactie.be/cm/vrtnieuws/2.43497/1.2612632?playlist=7.39637
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.738   1.000   0.021   1.000   1.000   0.119
# Bayes p: 0.002547
#
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   0.000   0.045
# Bayes p: 0.001692
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    2.053   1.000   0.016   1.000   1.000   0.064
# Bayes p: 0.001025
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:22 http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal/2.43555?video=1.2612481
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.738   1.000   0.021   1.000   1.000   0.126
# Bayes p: 0.002701
#
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   0.000   0.048
# Bayes p: 0.001788
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    2.053   1.000   0.016   1.000   1.000   0.067
# Bayes p: 0.001067
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:23 http://deredactie.be/cm/vrtnieuws/videozone/nieuws/binnenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.738   1.000   0.021   1.000   1.000   0.128
# Bayes p: 0.002731
#
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   0.000   0.052
# Bayes p: 0.001941
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    2.053   1.000   0.016   1.000   1.000   0.071
# Bayes p: 0.001139
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:24 http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    4.791   1.000   0.037   1.000   0.000   0.055
# Bayes p: 0.002075
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    2.053   1.000   0.016   1.000   1.000   0.072
# Bayes p: 0.001153
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   1.000   0.021   1.000   0.000   0.025
# Bayes p: 0.000527
#
#
# 	 WEB PAGE: 2: http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
# PAGE: i:25 http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   0.000   0.049
# Bayes p: 0.000789
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.738   1.000   0.021   1.000   1.000   0.042
# Bayes p: 0.000900
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   0.000   0.023
# Bayes p: 0.000494
#
#
# 	 WEB PAGE: 1: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:26 http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal/2.43555?video=1.2612492
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   0.000   0.062
# Bayes p: 0.000990
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   0.000   0.033
# Bayes p: 0.000700
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   0.000   0.025
# Bayes p: 0.000545
#
#
# 	 WEB PAGE: 1: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:27 http://deredactie.be/cm/vrtnieuws/videozone/nieuws
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   0.000   0.062
# Bayes p: 0.000990
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   0.000   0.033
# Bayes p: 0.000701
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   0.000   0.033
# Bayes p: 0.000700
#
#
# 	 WEB PAGE: 1: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:28 http://deredactie.be/cm/vrtnieuws/videozone/livestream
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   0.000   0.066
# Bayes p: 0.001054
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   0.000   0.037
# Bayes p: 0.000790
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   0.000   0.033
# Bayes p: 0.000701
#
#
# 	 WEB PAGE: 1: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:29 http://www.kuleuven.be/studenten/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.125
# Bayes p: 0.002674
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.125
# Bayes p: 0.002670
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/#bl=9;&f=-1,-1,-1,-1
#
#    0.684   0.996   0.005   0.996   1.000   0.083
# Bayes p: 0.000444
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:30 http://www.kuleuven.be/studenten/starters/index.html
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.146
# Bayes p: 0.003115
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.125
# Bayes p: 0.002674
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/CQ_50268945.htm
#
#    1.369   0.986   0.011   1.000   1.000   0.031
# Bayes p: 0.000334
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
# PAGE: i:31 http://nieuws.kuleuven.be/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.146
# Bayes p: 0.003119
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.146
# Bayes p: 0.003115
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/CQ_50268945.htm
#
#    1.369   0.986   0.011   1.000   1.000   0.031
# Bayes p: 0.000334
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:32 http://nieuws.kuleuven.be/taxonomy/term/59
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.146
# Bayes p: 0.003119
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.156
# Bayes p: 0.003338
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.021
# Bayes p: 0.000334
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:33 http://www.kuleuven.be/kuleuven/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.156
# Bayes p: 0.003342
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.156
# Bayes p: 0.003338
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.021
# Bayes p: 0.000334
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:34 http://www.kuleuven.be/studeren/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.156
# Bayes p: 0.003342
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.168
# Bayes p: 0.003597
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.038
# Bayes p: 0.000613
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:35 https://onderwijsaanbod.kuleuven.be/opleidingen/n/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.168
# Bayes p: 0.003602
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.168
# Bayes p: 0.003597
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.038
# Bayes p: 0.000613
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:36 https://onderwijsaanbod.kuleuven.be/opleidingen/n/#bl=9;&f=-1,-1,-1,-1
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.168
# Bayes p: 0.003602
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.180
# Bayes p: 0.003851
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.049
# Bayes p: 0.000789
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:37 https://onderwijsaanbod.kuleuven.be/opleidingen/n/#bl=9;-1&f=-1,-1,-1,-1
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.180
# Bayes p: 0.003856
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.180
# Bayes p: 0.003851
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.049
# Bayes p: 0.000789
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:38 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.180
# Bayes p: 0.003856
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.055
# Bayes p: 0.000890
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    2.738   0.387   0.021   0.927   1.000   0.023
# Bayes p: 0.000452
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:39 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.107
# Bayes p: 0.002276
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.055
# Bayes p: 0.000890
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    2.738   0.387   0.021   0.927   1.000   0.027
# Bayes p: 0.000526
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
# PAGE: i:40 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.180
# Bayes p: 0.003856
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.055
# Bayes p: 0.000890
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    2.738   0.387   0.021   0.927   1.000   0.023
# Bayes p: 0.000452
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:41 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.107
# Bayes p: 0.002276
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.055
# Bayes p: 0.000890
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    2.738   0.387   0.021   0.927   1.000   0.027
# Bayes p: 0.000526
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
# PAGE: i:42 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.180
# Bayes p: 0.003856
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.055
# Bayes p: 0.000890
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    2.738   0.387   0.021   0.927   1.000   0.023
# Bayes p: 0.000452
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:43 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.107
# Bayes p: 0.002276
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.055
# Bayes p: 0.000890
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    2.738   0.387   0.021   0.927   1.000   0.027
# Bayes p: 0.000526
#
#
# 	 WEB PAGE: 2: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:44 http://www.kuleuven.be/wieiswie/nl/person
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.131
# Bayes p: 0.002109
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.074
# Bayes p: 0.001580
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.066
# Bayes p: 0.001403
#
#
# 	 WEB PAGE: 1: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:45 https://eng.kuleuven.be/toekomstigestudenten
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.131
# Bayes p: 0.002109
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.074
# Bayes p: 0.001582
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.074
# Bayes p: 0.001580
#
#
# 	 WEB PAGE: 1: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:46 https://eng.kuleuven.be/toekomstigestudenten/burgerlijk-ingenieur
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.140
# Bayes p: 0.002244
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.074
# Bayes p: 0.001582
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.081
# Bayes p: 0.001726
#
#
# 	 WEB PAGE: 1: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:47 https://eng.kuleuven.be/studenten
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.081
# Bayes p: 0.001728
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.140
# Bayes p: 0.002244
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.081
# Bayes p: 0.001726
#
#
# 	 WEB PAGE: 2: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:48 https://eng.kuleuven.be/studenten/programmas/index.html
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.081
# Bayes p: 0.001728
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.087
# Bayes p: 0.001859
#
#
# https://eng.kuleuven.be/studenten
#
#    1.369   1.000   0.011   1.000   1.000   0.016
# Bayes p: 0.000175
#
#
# PAGE: i:49 https://eng.kuleuven.be/webcms/Shibboleth.sso/Login?target=https://eng.kuleuven.be/archief-hoofdpagina/recover/studenten/deadlines-2014-2015.pdf
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.081
# Bayes p: 0.001728
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    2.053   0.999   0.016   1.000   1.000   0.140
# Bayes p: 0.002244
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.081
# Bayes p: 0.001726
#
#
# 	 WEB PAGE: 2: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:50 https://eng.kuleuven.be/studenten/programmas/index.html
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    2.738   1.000   0.021   1.000   1.000   0.081
# Bayes p: 0.001728
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    2.738   0.721   0.021   0.999   1.000   0.087
# Bayes p: 0.001859
#
#
# https://eng.kuleuven.be/studenten
#
#    1.369   1.000   0.011   1.000   1.000   0.016
# Bayes p: 0.000175
#
#
# PAGE: i:51 https://eng.kuleuven.be/english/education/internationalisation
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://eng.kuleuven.be/english/education/internationalisation/Erasmus/exchange
#
#    0.684   1.000   0.005   1.000   1.000   0.083
# Bayes p: 0.000446
# (49, 5.4897959183673466)

# %%
train_and_validate('u23_1_training_data.csv','u23_1_test_data.csv')
# Out:
# 53
# PAGE: i:0 http://www.standaard.be/cnt/dmf20160325_02204284
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.173
# Bayes p: 0.007020
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.075
# Bayes p: 0.001640
#
#
# http://www.standaard.be/tag/aanslagen-brussel
#
#    1.994   1.000   0.016   1.000   1.000   0.047
# Bayes p: 0.000732
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/
#
# PAGE: i:1 http://www.standaard.be/plus
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.180
# Bayes p: 0.007304
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.079
# Bayes p: 0.001733
#
#
# http://www.standaard.be/tag/aanslagen-brussel
#
#    1.994   1.000   0.016   1.000   1.000   0.051
# Bayes p: 0.000798
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/
#
# PAGE: i:2 http://www.standaard.be/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.083
# Bayes p: 0.001816
#
#
# http://www.standaard.be/plus/ochtend
#
#    2.393   1.000   0.019   1.000   1.000   0.047
# Bayes p: 0.000873
#
#
# http://www.standaard.be/tag/aanslagen-brussel
#
#    1.994   1.000   0.016   1.000   1.000   0.055
# Bayes p: 0.000850
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/nieuws/binnenland
#
# PAGE: i:3 http://www.standaard.be/nieuws/binnenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.096
# Bayes p: 0.003882
#
#
# http://www.standaard.be/plus/ochtend
#
#    2.393   1.000   0.019   1.000   1.000   0.085
# Bayes p: 0.001594
#
#
# http://www.standaard.be/tag/aanslagen-brussel
#
#    1.994   1.000   0.016   1.000   1.000   0.078
# Bayes p: 0.001208
#
#
# 	 WEB PAGE: 2: http://www.standaard.be/plus/ochtend
#
# PAGE: i:4 http://www.standaard.be/cnt/dmf20160326_02205525
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.144
# Bayes p: 0.005817
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.063
# Bayes p: 0.001381
#
#
# http://www.standaard.be/tag/aanslagen-brussel
#
#    1.994   1.000   0.016   1.000   1.000   0.073
# Bayes p: 0.001135
#
#
# 	 WEB PAGE: 3: http://www.standaard.be/tag/aanslagen-brussel
#
# PAGE: i:5 http://www.standaard.be/tag/aanslagen-brussel
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.099
# Bayes p: 0.004005
#
#
# http://www.standaard.be/cnt/dmf20160324_02200483
#
#    1.595   1.000   0.012   1.000   1.000   0.099
# Bayes p: 0.001232
#
#
# http://www.standaard.be/plus/ochtend
#
#    2.393   1.000   0.019   1.000   1.000   0.049
# Bayes p: 0.000915
#
#
# 	 WEB PAGE: 3: http://www.standaard.be/plus/ochtend
#
# PAGE: i:6 http://www.standaard.be/nieuws/buitenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.393   1.000   0.019   1.000   1.000   0.153
# Bayes p: 0.002862
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.056
# Bayes p: 0.001215
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.015
# Bayes p: 0.000607
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:7 http://www.standaard.be/plus/krant/opinie/opinies
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.393   1.000   0.019   1.000   1.000   0.153
# Bayes p: 0.002859
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.044
# Bayes p: 0.000958
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.012
# Bayes p: 0.000498
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:8 http://www.standaard.be/nieuws/buitenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.393   1.000   0.019   1.000   1.000   0.153
# Bayes p: 0.002862
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.056
# Bayes p: 0.001215
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.015
# Bayes p: 0.000607
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:9 http://www.standaard.be/nieuws/sport
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.393   1.000   0.019   1.000   1.000   0.194
# Bayes p: 0.003628
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.032
# Bayes p: 0.001302
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.070
# Bayes p: 0.001520
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:10 http://www.standaard.be/nieuws/sport/voetbal
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.393   1.000   0.019   1.000   1.000   0.195
# Bayes p: 0.003647
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.037
# Bayes p: 0.001496
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.077
# Bayes p: 0.001680
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:11 http://www.standaard.be/nieuws/sport/voetbal?page=2
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.393   1.000   0.019   1.000   1.000   0.204
# Bayes p: 0.003822
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.044
# Bayes p: 0.001786
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.079
# Bayes p: 0.001728
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:12 http://www.standaard.be/cnt/dmf20160325_02203505
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.393   1.000   0.019   1.000   1.000   0.206
# Bayes p: 0.003851
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.049
# Bayes p: 0.001994
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.085
# Bayes p: 0.001856
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:13 http://www.standaard.be/plus/ochtend
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.056
# Bayes p: 0.002248
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.088
# Bayes p: 0.001910
#
#
# http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F4
#
#    1.196   1.000   0.009   1.000   1.000   0.103
# Bayes p: 0.000963
#
#
# 	 WEB PAGE: 3: http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F4
#
# PAGE: i:14 http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F4
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/plus/ochtend
#
#    2.393   1.000   0.019   1.000   1.000   0.206
# Bayes p: 0.003851
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.049
# Bayes p: 0.001994
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.085
# Bayes p: 0.001856
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/plus/ochtend
#
# PAGE: i:15 http://www.standaard.be/plus/ochtend
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.056
# Bayes p: 0.002248
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   1.000   0.088
# Bayes p: 0.001910
#
#
# http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F4
#
#    1.196   1.000   0.009   1.000   1.000   0.103
# Bayes p: 0.000963
#
#
# PAGE: i:16 http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F30
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.791   1.000   0.022   1.000   0.000   0.094
# Bayes p: 0.002043
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   1.000   0.032
# Bayes p: 0.001312
#
#
# http://deredactie.be/cm/vrtnieuws/videozone
#
#    1.994   1.000   0.016   1.000   0.000   0.086
# Bayes p: 0.001341
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:17 https://search.yahoo.com/yhs/search?p=deredactie&ei=UTF-8&hspart=mozilla&hsimp=yhs-002
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.791   1.000   0.022   1.000   0.000   0.097
# Bayes p: 0.002108
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   0.000   0.037
# Bayes p: 0.001506
#
#
# http://deredactie.be/cm/vrtnieuws/videozone
#
#    1.994   1.000   0.016   1.000   0.000   0.087
# Bayes p: 0.001354
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:18 http://deredactie.be/cm/vrtnieuws
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.791   1.000   0.022   1.000   1.000   0.101
# Bayes p: 0.002207
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   0.000   0.041
# Bayes p: 0.001667
#
#
# http://deredactie.be/cm/vrtnieuws/videozone
#
#    1.994   1.000   0.016   1.000   1.000   0.088
# Bayes p: 0.001367
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:19 http://deredactie.be/cm/vrtnieuws/videozone
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.791   1.000   0.022   1.000   1.000   0.107
# Bayes p: 0.002326
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   0.000   0.046
# Bayes p: 0.001883
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    1.994   1.000   0.016   1.000   1.000   0.074
# Bayes p: 0.001157
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:20 http://deredactie.be/cm/vrtnieuws/videozone/nieuws/politiek/1.2612587
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.791   1.000   0.022   1.000   1.000   0.073
# Bayes p: 0.001597
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   0.000   0.031
# Bayes p: 0.001263
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    1.994   1.000   0.016   1.000   1.000   0.091
# Bayes p: 0.001421
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:21 http://deredactie.be/cm/vrtnieuws/2.43497/1.2612632?playlist=7.39637
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.791   1.000   0.022   1.000   1.000   0.124
# Bayes p: 0.002715
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   0.000   0.054
# Bayes p: 0.002204
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    1.994   1.000   0.016   1.000   1.000   0.060
# Bayes p: 0.000934
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:22 http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal/2.43555?video=1.2612481
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.791   1.000   0.022   1.000   1.000   0.131
# Bayes p: 0.002853
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   0.000   0.058
# Bayes p: 0.002350
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    1.994   1.000   0.016   1.000   1.000   0.064
# Bayes p: 0.000991
#
#
# 	 WEB PAGE: 1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:23 http://deredactie.be/cm/vrtnieuws/videozone/nieuws/binnenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   0.000   0.064
# Bayes p: 0.002580
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.791   1.000   0.022   1.000   1.000   0.133
# Bayes p: 0.002893
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    1.994   1.000   0.016   1.000   1.000   0.068
# Bayes p: 0.001057
#
#
# 	 WEB PAGE: 2: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# PAGE: i:24 http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   0.000   0.068
# Bayes p: 0.002756
#
#
# http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    1.994   1.000   0.016   1.000   1.000   0.069
# Bayes p: 0.001072
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.791   1.000   0.022   1.000   0.000   0.028
# Bayes p: 0.000618
#
#
# 	 WEB PAGE: 2: http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
# PAGE: i:25 http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
#    2.791   1.000   0.022   1.000   1.000   0.052
# Bayes p: 0.001141
#
#
# http://www.standaard.be/
#
#    5.184   1.000   0.040   1.000   0.000   0.023
# Bayes p: 0.000940
#
#
# https://search.yahoo.com/yhs/search?p=kuleuven+ingenieurswetenschappen&ei=UTF-8&hspart=mozilla&hsimp=yhs-002
#
#    1.595   0.998   0.012   1.000   0.000   0.063
# Bayes p: 0.000789
#
#
# PAGE: i:26 http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal/2.43555?video=1.2612492
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://search.yahoo.com/yhs/search?p=kuleuven+ingenieurswetenschappen&ei=UTF-8&hspart=mozilla&hsimp=yhs-002
#
#    1.595   0.998   0.012   1.000   0.000   0.083
# Bayes p: 0.001038
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   0.000   0.041
# Bayes p: 0.000640
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   0.000   0.034
# Bayes p: 0.000535
#
#
# 	 WEB PAGE: 2: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
# PAGE: i:27 http://deredactie.be/cm/vrtnieuws/videozone/nieuws
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   0.000   0.041
# Bayes p: 0.000640
#
#
# https://search.yahoo.com/yhs/search?p=kuleuven+ingenieurswetenschappen&ei=UTF-8&hspart=mozilla&hsimp=yhs-002
#
#    1.595   0.998   0.012   1.000   0.000   0.083
# Bayes p: 0.001038
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   0.000   0.041
# Bayes p: 0.000640
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:28 http://deredactie.be/cm/vrtnieuws/videozone/livestream
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   0.000   0.041
# Bayes p: 0.000640
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   0.000   0.044
# Bayes p: 0.000687
#
#
# https://search.yahoo.com/yhs/search?p=kuleuven+ingenieurswetenschappen&ei=UTF-8&hspart=mozilla&hsimp=yhs-002
#
#    1.595   0.998   0.012   1.000   0.000   0.083
# Bayes p: 0.001038
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:29 http://www.kuleuven.be/studenten/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.117
# Bayes p: 0.001817
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.117
# Bayes p: 0.001817
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/CQ_50268945.htm
#
#    1.595   0.986   0.012   1.000   1.000   0.033
# Bayes p: 0.000415
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:30 http://www.kuleuven.be/studenten/starters/index.html
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.130
# Bayes p: 0.002024
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.117
# Bayes p: 0.001817
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/CQ_50268945.htm
#
#    1.595   0.986   0.012   1.000   1.000   0.047
# Bayes p: 0.000582
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
# PAGE: i:31 http://nieuws.kuleuven.be/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.130
# Bayes p: 0.002025
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.130
# Bayes p: 0.002024
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/CQ_50268945.htm
#
#    1.595   0.986   0.012   1.000   1.000   0.047
# Bayes p: 0.000582
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:32 http://nieuws.kuleuven.be/taxonomy/term/59
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.130
# Bayes p: 0.002025
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.135
# Bayes p: 0.002108
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/CQ_50268945.htm
#
#    1.595   0.986   0.012   1.000   1.000   0.052
# Bayes p: 0.000648
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:33 http://www.kuleuven.be/kuleuven/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.135
# Bayes p: 0.002108
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.135
# Bayes p: 0.002108
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.595   1.000   0.012   1.000   1.000   0.049
# Bayes p: 0.000615
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:34 http://www.kuleuven.be/studeren/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.135
# Bayes p: 0.002108
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.146
# Bayes p: 0.002271
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.595   1.000   0.012   1.000   1.000   0.052
# Bayes p: 0.000648
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:35 https://onderwijsaanbod.kuleuven.be/opleidingen/n/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.146
# Bayes p: 0.002271
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.146
# Bayes p: 0.002271
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.595   1.000   0.012   1.000   1.000   0.053
# Bayes p: 0.000661
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:36 https://onderwijsaanbod.kuleuven.be/opleidingen/n/#bl=9;&f=-1,-1,-1,-1
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.146
# Bayes p: 0.002271
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.155
# Bayes p: 0.002420
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    3.190   0.387   0.025   0.997   1.000   0.019
# Bayes p: 0.000483
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:37 https://onderwijsaanbod.kuleuven.be/opleidingen/n/#bl=9;-1&f=-1,-1,-1,-1
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.155
# Bayes p: 0.002421
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.155
# Bayes p: 0.002420
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    3.190   0.387   0.025   0.997   1.000   0.027
# Bayes p: 0.000666
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:38 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.155
# Bayes p: 0.002421
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    3.190   0.387   0.025   0.997   1.000   0.035
# Bayes p: 0.000858
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.595   1.000   0.012   1.000   1.000   0.058
# Bayes p: 0.000727
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:39 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    3.190   0.387   0.025   0.997   1.000   0.039
# Bayes p: 0.000975
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.079
# Bayes p: 0.001224
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.393   1.000   0.019   1.000   1.000   0.028
# Bayes p: 0.000528
#
#
# 	 WEB PAGE: 2: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
# PAGE: i:40 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.155
# Bayes p: 0.002421
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    3.190   0.387   0.025   0.997   1.000   0.035
# Bayes p: 0.000858
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.595   1.000   0.012   1.000   1.000   0.058
# Bayes p: 0.000727
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:41 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    3.190   0.387   0.025   0.997   1.000   0.039
# Bayes p: 0.000975
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.079
# Bayes p: 0.001224
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.393   1.000   0.019   1.000   1.000   0.028
# Bayes p: 0.000528
#
#
# 	 WEB PAGE: 2: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
# PAGE: i:42 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.155
# Bayes p: 0.002421
#
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    3.190   0.387   0.025   0.997   1.000   0.035
# Bayes p: 0.000858
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.595   1.000   0.012   1.000   1.000   0.058
# Bayes p: 0.000727
#
#
# 	 WEB PAGE: 1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# PAGE: i:43 https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/syllabi/e/H0T25AE.htm
#
#    3.190   0.387   0.025   0.997   1.000   0.039
# Bayes p: 0.000975
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.079
# Bayes p: 0.001224
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm#bl=01,03,0303,030301,030302
#
#    2.393   1.000   0.019   1.000   1.000   0.028
# Bayes p: 0.000528
#
#
# PAGE: i:44 http://www.kuleuven.be/wieiswie/nl/person
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.082
# Bayes p: 0.001280
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.088
# Bayes p: 0.001374
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    1.595   0.999   0.012   1.000   1.000   0.119
# Bayes p: 0.001487
#
#
# 	 WEB PAGE: 3: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:45 https://eng.kuleuven.be/toekomstigestudenten
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.088
# Bayes p: 0.001374
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.088
# Bayes p: 0.001374
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    1.595   0.999   0.012   1.000   1.000   0.119
# Bayes p: 0.001487
#
#
# 	 WEB PAGE: 3: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:46 https://eng.kuleuven.be/toekomstigestudenten/burgerlijk-ingenieur
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.088
# Bayes p: 0.001374
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.095
# Bayes p: 0.001479
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    1.595   0.999   0.012   1.000   1.000   0.127
# Bayes p: 0.001582
#
#
# 	 WEB PAGE: 3: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:47 https://eng.kuleuven.be/studenten
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.095
# Bayes p: 0.001479
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.095
# Bayes p: 0.001479
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    1.595   0.999   0.012   1.000   1.000   0.127
# Bayes p: 0.001582
#
#
# 	 WEB PAGE: 3: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:48 https://eng.kuleuven.be/studenten/programmas/index.html
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.095
# Bayes p: 0.001479
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.101
# Bayes p: 0.001580
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.595   1.000   0.012   1.000   1.000   0.035
# Bayes p: 0.000440
#
#
# PAGE: i:49 https://eng.kuleuven.be/webcms/Shibboleth.sso/Login?target=https://eng.kuleuven.be/archief-hoofdpagina/recover/studenten/deadlines-2014-2015.pdf
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.095
# Bayes p: 0.001479
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.095
# Bayes p: 0.001479
#
#
# https://eng.kuleuven.be/studenten/programmas/index.html
#
#    1.595   0.999   0.012   1.000   1.000   0.127
# Bayes p: 0.001582
#
#
# 	 WEB PAGE: 3: https://eng.kuleuven.be/studenten/programmas/index.html
#
# PAGE: i:50 https://eng.kuleuven.be/studenten/programmas/index.html
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
#    1.994   1.000   0.016   1.000   1.000   0.095
# Bayes p: 0.001479
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
#    1.994   0.721   0.016   1.000   1.000   0.101
# Bayes p: 0.001580
#
#
# https://onderwijsaanbod.kuleuven.be/opleidingen/n/SC_51230411.htm
#
#    1.595   1.000   0.012   1.000   1.000   0.035
# Bayes p: 0.000440
#
#
# PAGE: i:51 https://eng.kuleuven.be/english/education/internationalisation
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# https://eng.kuleuven.be/english/education/internationalisation/Erasmus/exchange
#
#    0.399   1.000   0.003   1.000   1.000   0.083
# Bayes p: 0.000260
# (46, 4.2173913043478262)

# %%
validate_directory()
# Out:
# {'u10': ['./data/u10_1.csv'], 'u19': ['./data/u19_1.csv', './data/u19_2.csv', './data/u19_3.csv', './data/u19_4.csv', './data/u19_5.csv', './data/u19_6.csv', './data/u19_7.csv', './data/u19_8.csv'], 'u14': ['./data/u14_1.csv', './data/u14_2.csv', './data/u14_3.csv', './data/u14_4.csv', './data/u14_5.csv', './data/u14_6.csv', './data/u14_7.csv', './data/u14_8.csv'], 'u12': ['./data/u12_1.csv', './data/u12_2.csv', './data/u12_3.csv', './data/u12_4.csv', './data/u12_5.csv'], 'u15': ['./data/u15_1.csv', './data/u15_2.csv', './data/u15_3.csv', './data/u15_4.csv', './data/u15_5.csv'], 'u3': ['./data/u3_1.csv'], 'u18': ['./data/u18_1.csv', './data/u18_2.csv', './data/u18_3.csv', './data/u18_4.csv', './data/u18_5.csv'], 'u7': ['./data/u7_1.csv'], 'u2': ['./data/u2_1.csv', './data/u2_2.csv', './data/u2_3.csv', './data/u2_4.csv', './data/u2_5.csv', './data/u2_6.csv', './data/u2_7.csv'], 'u20': ['./data/u20_1.csv', './data/u20_2.csv'], 'u5': ['./data/u5_1.csv', './data/u5_10.csv', './data/u5_11.csv', './data/u5_12.csv', './data/u5_2.csv', './data/u5_3.csv', './data/u5_4.csv', './data/u5_5.csv', './data/u5_6.csv', './data/u5_7.csv', './data/u5_8.csv', './data/u5_9.csv'], 'u22': ['./data/u22_1.csv', './data/u22_2.csv', './data/u22_3.csv'], 'u1': ['./data/u1_1.csv', './data/u1_2.csv', './data/u1_3.csv'], 'u13': ['./data/u13_1.csv', './data/u13_2.csv', './data/u13_3.csv'], 'u16': ['./data/u16_1.csv'], 'u26': ['./data/u26_1.csv', './data/u26_2.csv', './data/u26_3.csv', './data/u26_4.csv', './data/u26_5.csv', './data/u26_6.csv', './data/u26_7.csv', './data/u26_8.csv', './data/u26_9.csv'], 'u11': ['./data/u11_1.csv'], 'u23': ['./data/u23_1.csv'], 'u4': ['./data/u4_1.csv', './data/u4_2.csv', './data/u4_3.csv', './data/u4_4.csv', './data/u4_5.csv', './data/u4_6.csv'], 'u6': ['./data/u6_1.csv'], 'u25': ['./data/u25_1.csv', './data/u25_10.csv', './data/u25_2.csv', './data/u25_3.csv', './data/u25_4.csv', './data/u25_5.csv', './data/u25_6.csv', './data/u25_7.csv', './data/u25_8.csv', './data/u25_9.csv'], 'u8': ['./data/u8_1.csv', './data/u8_2.csv', './data/u8_3.csv', './data/u8_4.csv', './data/u8_5.csv'], 'u17': ['./data/u17_1.csv'], 'u27': ['./data/u27_1.csv'], 'u24': ['./data/u24_1.csv', './data/u24_2.csv', './data/u24_3.csv'], 'u21': ['./data/u21_1.csv', './data/u21_2.csv', './data/u21_3.csv', './data/u21_4.csv', './data/u21_5.csv', './data/u21_6.csv', './data/u21_7.csv', './data/u21_8.csv', './data/u21_9.csv'], 'u9': ['./data/u9_1.csv', './data/u9_2.csv']}
# 0.6996587030716723
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-59e5585db64d> in <module>()
# ----> 1 validate_directory()
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/model_validator.py in validate_directory(directory)
#      77         print(str(users))
#      78         for user in users:
# ---> 79                 result = validate_user(users[user])
#      80                 prediction_list.append(result[0])
#      81                 distance_list.append(result[1])
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/model_validator.py in validate_user(user_files)
#     108                         pred.learn_from(open(file),1)
#     109                 elif fraction > 0:
# --> 110                         pred.learn_from(open(file),fraction)
#     111                         pages = preprocess(file,fraction)
#     112                         result = validate(pages)
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/url_predictor.py in learn_from(csv_file_handle, fraction)
#      54     lines = csv_file_handle.readlines()
#      55     # Make a list of 'event' dictionaries.
# ---> 56     events = parse(lines)
#      57     # Make a list of 'page visit' dictionaries.
#      58     page_visits = make_page_visits(events)
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/url_predictor.py in parse(lines)
#      77         # Parse the line as JSON.
#      78         # Add brackets to line so it is valid JSON.
# ---> 79         data = json.loads('[{}]'.format(line))
#      80         # Make a new dictionary and add it to the events to be
#      81         # returned.
#
# /Users/jorntuyls/anaconda/envs/kul-ml/lib/python3.5/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# /Users/jorntuyls/anaconda/envs/kul-ml/lib/python3.5/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /Users/jorntuyls/anaconda/envs/kul-ml/lib/python3.5/json/decoder.py in raw_decode(self, s, idx)
#     353         """
#     354         try:
# --> 355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
#     357             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Invalid control character at: line 1 column 107 (char 106)

# %%
from graph_vis import *

# %%
visualise('u23_1.csv')
# Out:
# {'kuleuven.be': '#ff8000', 'sporza.be': '#00ffbf', 'standaard.be': '#ff0000', 'cnn.com': '#00bfff', 'yahoo.com': '#80ff00', 'deredactie.be': '#ffff00'}

# %%
s = 'u1_1.csv'

# %%
a = s.split('_')

# %%
a
# Out:
# ['u1', '1.csv']

# %%
s
# Out:
# 'u1_1.csv'

# %%
int(0.7*4)
# Out:
# 2
