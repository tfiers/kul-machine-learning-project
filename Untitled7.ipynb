# %%
from model_validator import *

# %%
validate_directory()
# Out:
# u2
# VALID FILE: ./data/u2_1.csv
# 1111111
# VALID FILE: ./data/u2_2.csv
# 1111111
# VALID FILE: ./data/u2_3.csv
# 1111111
# VALID FILE: ./data/u2_4.csv
# 1111111
# VALID FILE: ./data/u2_5.csv
# 2222222
# 6
# PAGE: i:0 http://uk.businessinsider.com/dodocase-launches-pre-orders-for-smartvr-headset-that-fits-in-your-pocket-2016-3
#
# PAGE: i:1 https://www.google.be/search?q=conacyt&ie=utf-8&oe=utf-8&gws_rd=cr&ei=RsjdVuufIsmVaLf8kMAF
#
# PAGE: i:2 http://www.conacyt.mx/
#
# PAGE: i:3 http://www.conacyt.mx/index.php/becas-y-posgrados/becas-en-el-extranjero
#
# PAGE: i:4 http://www.conacyt.mx/index.php/avisos-becas-extranjero
#
# VALID FILE: ./data/u2_6.csv
# 3333333
# 17
# PAGE: i:0 https://www.google.be/search?q=wheater&ie=utf-8&oe=utf-8&gws_rd=cr&ei=g6reVpgjyP9oy7ekuAw
#
# PAGE: i:1 https://www.google.be/search?q=wheater&ie=utf-8&oe=utf-8&gws_rd=cr&ei=g6reVpgjyP9oy7ekuAw#cns=0&gws_rd=cr
#
# PAGE: i:2 https://weather.com/weather/today/l/50.87,4.69
#
# ...

# %%
validate_user(['./data/u21_1.csv','./data/u21_2.csv','./data/u21_3.csv','./data/u21_4.csv','./data/u21_5.csv','./data/u21_6.csv','./data/u21_7.csv','./data/u21_8.csv','./data/u21_9.csv'])

# %%
train_and_validate('u23_1.csv','u23_1_test_data.csv')
# Out:
# 53
# PAGE: i:0 http://www.standaard.be/cnt/dmf20160325_02204284
#
# http://www.standaard.be/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav  minlen
#    4.766   1.000   0.037   1.000   1.000   0.082   2.000
#
# Bayes p:      0.003048
# Len weighted: 0.003688
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav  minlen
#    2.723   1.000   0.021   1.000   1.000   0.038   3.000
#
# Bayes p:      0.000808
# Len weighted: 0.001075
#
#
# http://www.standaard.be/plus/ochtend
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav  minlen
#    2.723   1.000   0.021   1.000   1.000   0.019   4.000
#
# Bayes p:      0.000402
# Len weighted: 0.000589
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/
#
# PAGE: i:1 http://www.standaard.be/plus
#
# http://www.standaard.be/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav  minlen
#    4.741   1.000   0.037   1.000   1.000   0.085   1.000
#
# Bayes p:      0.003137
# Len weighted: 0.003450
#
#
# ...

# %%
train_and_validate('u23_1_training_data.csv','u23_1_test_data.csv')
# Out:
# 53
# PAGE: i:0 http://www.standaard.be/cnt/dmf20160325_02204284
#
# PAGE: i:1 http://www.standaard.be/plus
#
# PAGE: i:2 http://www.standaard.be/
#
# http://www.standaard.be/nieuws/binnenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav  minlen
#    2.190   1.672   0.022   0.037   1.000   0.066   1.000
#
# Bayes p:      5.354E-05
# Len-weighted: 5.890E-05
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav  minlen
#    1.460   1.917   0.015   0.028   1.000   0.040   1.000
#
# Bayes p:      1.648E-05
# Len-weighted: 1.813E-05
#
#
# http://www.standaard.be/cnt/dmf20160324_02200483
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav  minlen
#    1.460   1.722   0.015   0.025   1.000   0.036   3.000
#
# Bayes p:      1.340E-05
# Len-weighted: 1.784E-05
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/nieuws/binnenland
#
# PAGE: i:3 http://www.standaard.be/nieuws/binnenland
#
# http://www.standaard.be/
#
# ...

# %%
validate_directory()
# Out:
# u25
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-59e5585db64d> in <module>()
# ----> 1 validate_directory()
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/model_validator.py in validate_directory(directory)
#      77         for user in users:
#      78                 print(user)
# ---> 79                 result = validate_user(users[user])
#      80                 prediction_list.append(result[0])
#      81                 distance_list.append(result[1])
#
# /Users/jorntuyls/Documents/workspaces/ml/kul-machine-learning-project/model_validator.py in validate_user(user_files)
#     103         for file in user_files:
#     104                 openfile = open(file).readlines()
# --> 105                 fraction = (test_data_start - page_counter) / len(openfile)
#     106                 if fraction >= 1:
# ...

# %%
from graph_vis import *

# %%
visualise('u23_1.csv')
# Out:
# {'kuleuven.be': '#ff8000', 'sporza.be': '#00ffbf', 'standaard.be': '#ff0000', 'cnn.com': '#00bfff', 'yahoo.com': '#80ff00', 'deredactie.be': '#ffff00'}

# %%
s = 'u1_1.csv'

# %%
a = s.split('_')

# %%
a
# Out:
# ['u1', '1.csv']

# %%
s
# Out:
# 'u1_1.csv'

# %%
int(0.7*4)
# Out:
# 2
