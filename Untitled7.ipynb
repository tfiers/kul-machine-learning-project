# %%
from model_validator import *

# %%
validate_directory()
# Out:
# {'u1': ['u1_1.csv', 'u1_2.csv', 'u1_3.csv'],
#  'u10': ['u10_1.csv'],
#  'u11': ['u11_1.csv'],
#  'u12': ['u12_1.csv', 'u12_2.csv', 'u12_3.csv', 'u12_4.csv', 'u12_5.csv'],
#  'u13': ['u13_1.csv', 'u13_2.csv', 'u13_3.csv'],
#  'u14': ['u14_1.csv',
#   'u14_2.csv',
#   'u14_3.csv',
#   'u14_4.csv',
#   'u14_5.csv',
#   'u14_6.csv',
#   'u14_7.csv',
#   'u14_8.csv'],
#  'u15': ['u15_1.csv', 'u15_2.csv', 'u15_3.csv', 'u15_4.csv', 'u15_5.csv'],
#  'u16': ['u16_1.csv'],
#  'u17': ['u17_1.csv'],
#  'u18': ['u18_1.csv', 'u18_2.csv', 'u18_3.csv', 'u18_4.csv', 'u18_5.csv'],
#  'u19': ['u19_1.csv',
#   'u19_2.csv',
#   'u19_3.csv',
#   'u19_4.csv',
#   'u19_5.csv',
#   'u19_6.csv',
#   'u19_7.csv',
#   'u19_8.csv'],
#  'u2': ['u2_1.csv',
#   'u2_2.csv',
#   'u2_3.csv',
#   'u2_4.csv',
#   'u2_5.csv',
#   'u2_6.csv',
#   'u2_7.csv'],
#  'u20': ['u20_1.csv', 'u20_2.csv'],
#  'u21': ['u21_1.csv',
#   'u21_2.csv',
#   'u21_3.csv',
#   'u21_4.csv',
#   'u21_5.csv',
#   'u21_6.csv',
#   'u21_7.csv',
# ...

# %%
train_and_validate('u23_1.csv','u23_1_test_data.csv')
# Out:
# 53
# PAGE: i:0 http://www.standaard.be/cnt/dmf20160325_02204284
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    4.791   0.957   0.037   0.036   1.000   6.767
# Bayes p: 0.009076
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.369  23.500   0.011   0.251   1.000   2.049
# Bayes p: 0.005507
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   0.443   0.021   0.009   1.000   3.701
# Bayes p: 0.000751
#
#
# 	 WEB PAGE: 1: http://www.standaard.be/
#
# PAGE: i:1 http://www.standaard.be/plus
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    4.791   0.957   0.037   0.036   1.000   6.369
# Bayes p: 0.008542
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.369  23.500   0.011   0.251   1.000   1.990
# Bayes p: 0.005350
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.738   0.443   0.021   0.009   1.000   3.556
# Bayes p: 0.000722
#
#
# ...

# %%
train_and_validate('u23_1_training_data.csv','u23_1_test_data.csv')
# Out:
# 53
# PAGE: i:0 http://www.standaard.be/cnt/dmf20160325_02204284
# PAGE: i:1 http://www.standaard.be/plus
# PAGE: i:2 http://www.standaard.be/
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.463  17.437   0.015   0.260   1.000   2.675
# Bayes p: 0.010390
#
#
# http://www.standaard.be/nieuws/binnenland
#
#    2.194   0.396   0.022   0.009   1.000   4.062
# Bayes p: 0.000807
#
#
# http://www.standaard.be/cnt/dmf20160324_02200483
#
#    1.463   0.281   0.015   0.004   1.000   2.706
# Bayes p: 0.000170
#
#
# 	 WEB PAGE: 2: http://www.standaard.be/nieuws/binnenland
#
# PAGE: i:3 http://www.standaard.be/nieuws/binnenland
#
#    N_rel  dt_rel  N_prop dt_prop  same_d  p_trav
#
# http://www.standaard.be/
#
#    4.388   0.818   0.045   0.037   1.000   7.269
# Bayes p: 0.011924
#
#
# http://www.standaard.be/cnt/dmf20160326_02205478
#
#    1.463  17.437   0.015   0.260   1.000   2.926
# Bayes p: 0.011365
#
#
# ...

# %%
ls
# Out:
# Experiments/                    graph_vis
# KUL_README                      graph_vis.py
# Literature/                     model_validator.py
# README.md                       model_validator.pyc
# Report/                         requirements.txt
# Time management sheet link.rtf  research.bib
# Untitled.ipynb                  research.log
# Untitled1.ipynb                 u23_1.csv
# Untitled2.ipynb                 u23_1_test.csv
# Untitled3.ipynb                 u23_1_test_data.csv
# Untitled4.ipynb                 u23_1_training_data.csv
# Untitled5.ipynb                 urlStreamHandler.py
# Untitled6.ipynb                 urlStreamHandler.user.js
# Untitled7.ipynb                 url_predictor.py
# __pycache__/                    url_predictor.pyc
# data/

# %%
from graph_vis import *

# %%
visualise('u23_1.csv')
# Out:
# {'kuleuven.be': '#ff8000', 'sporza.be': '#00ffbf', 'standaard.be': '#ff0000', 'cnn.com': '#00bfff', 'yahoo.com': '#80ff00', 'deredactie.be': '#ffff00'}

# %%
s = 'u1_1.csv'

# %%
a = s.split('_')

# %%
a
# Out:
# ['u1', '1.csv']

# %%
s
# Out:
# 'u1_1.csv'
