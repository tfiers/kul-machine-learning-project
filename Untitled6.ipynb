# %%
from model_validator import *

# %%
train_and_validate('u23_1_training_data.csv','u23_1_test_data.csv')
# Out:
# 53
# j: 0
# 0: http://www.standaard.be/cnt/dmf20160325_02204284
#
# 	1: http://www.standaard.be/
#
# 	2: http://www.standaard.be/
#
# 	2 pages in between
#
# j: 0
# 1: http://www.standaard.be/plus
#
# 	1: http://www.standaard.be/
#
# 	2: http://www.standaard.be/
#
# 	1 pages in between
#
# j: 0
# j: 1
# 2: http://www.standaard.be/
#
# 	2: http://www.standaard.be/nieuws/binnenland
#
# 	3: http://www.standaard.be/nieuws/binnenland
#
# 	1 pages in between
#
# j: 0
# j: 1
# j: 2
# 3: http://www.standaard.be/nieuws/binnenland
#
# 	3: http://www.standaard.be/tag/aanslagen-brussel
#
# 	5: http://www.standaard.be/tag/aanslagen-brussel
#
# 	2 pages in between
#
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# j: 0
# 18: http://deredactie.be/cm/vrtnieuws
#
# 	1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# 	24: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# 	6 pages in between
#
# j: 0
# 19: http://deredactie.be/cm/vrtnieuws/videozone
#
# 	1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# 	24: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# 	5 pages in between
#
# j: 0
# 20: http://deredactie.be/cm/vrtnieuws/videozone/nieuws/politiek/1.2612587
#
# 	1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# 	24: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# 	4 pages in between
#
# j: 0
# 21: http://deredactie.be/cm/vrtnieuws/2.43497/1.2612632?playlist=7.39637
#
# 	1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# 	24: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# 	3 pages in between
#
# j: 0
# 22: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal/2.43555?video=1.2612481
#
# 	1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# 	24: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# 	2 pages in between
#
# j: 0
# 23: http://deredactie.be/cm/vrtnieuws/videozone/nieuws/binnenland
#
# 	1: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# 	24: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# 	1 pages in between
#
# j: 0
# 24: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal
#
# 	1: http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
# 	25: http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken
#
# 	1 pages in between
#
# j: 0
# j: 1
# j: 2
# j: 0
# 26: http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal/2.43555?video=1.2612492
#
# 	1: http://deredactie.be/cm/vrtnieuws/videozone/livestream
#
# 	28: http://deredactie.be/cm/vrtnieuws/videozone/livestream
#
# 	2 pages in between
#
# j: 0
# 27: http://deredactie.be/cm/vrtnieuws/videozone/nieuws
#
# 	1: http://deredactie.be/cm/vrtnieuws/videozone/livestream
#
# 	28: http://deredactie.be/cm/vrtnieuws/videozone/livestream
#
# 	1 pages in between
#
# j: 0
# j: 1
# j: 2
# j: 0
# 29: http://www.kuleuven.be/studenten/
#
# 	1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	39: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	10 pages in between
#
# j: 0
# 30: http://www.kuleuven.be/studenten/starters/index.html
#
# 	1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	39: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	9 pages in between
#
# j: 0
# 31: http://nieuws.kuleuven.be/
#
# 	1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	39: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	8 pages in between
#
# j: 0
# 32: http://nieuws.kuleuven.be/taxonomy/term/59
#
# 	1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	39: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	7 pages in between
#
# j: 0
# 33: http://www.kuleuven.be/kuleuven/
#
# 	1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	39: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	6 pages in between
#
# j: 0
# 34: http://www.kuleuven.be/studeren/
#
# 	1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	39: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	5 pages in between
#
# j: 0
# 35: https://onderwijsaanbod.kuleuven.be/opleidingen/n/
#
# 	1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	39: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	4 pages in between
#
# j: 0
# 36: https://onderwijsaanbod.kuleuven.be/opleidingen/n/#bl=9;&f=-1,-1,-1,-1
#
# 	1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	39: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	3 pages in between
#
# j: 0
# 37: https://onderwijsaanbod.kuleuven.be/opleidingen/n/#bl=9;-1&f=-1,-1,-1,-1
#
# 	1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	39: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	2 pages in between
#
# j: 0
# 38: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
# 	1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	39: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	1 pages in between
#
# j: 0
# j: 1
# j: 2
# j: 0
# 40: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
# 	1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	41: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	1 pages in between
#
# j: 0
# j: 1
# j: 2
# j: 0
# 42: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm
#
# 	1: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	43: https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all
#
# 	1 pages in between
#
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# 44: http://www.kuleuven.be/wieiswie/nl/person
#
# 	3: https://eng.kuleuven.be/studenten
#
# 	47: https://eng.kuleuven.be/studenten
#
# 	3 pages in between
#
# j: 0
# j: 1
# j: 2
# 45: https://eng.kuleuven.be/toekomstigestudenten
#
# 	3: https://eng.kuleuven.be/studenten
#
# 	47: https://eng.kuleuven.be/studenten
#
# 	2 pages in between
#
# j: 0
# j: 1
# j: 2
# 46: https://eng.kuleuven.be/toekomstigestudenten/burgerlijk-ingenieur
#
# 	3: https://eng.kuleuven.be/studenten/programmas/index.html
#
# 	48: https://eng.kuleuven.be/studenten/programmas/index.html
#
# 	2 pages in between
#
# j: 0
# j: 1
# j: 2
# 47: https://eng.kuleuven.be/studenten
#
# 	3: https://eng.kuleuven.be/studenten/programmas/index.html
#
# 	48: https://eng.kuleuven.be/studenten/programmas/index.html
#
# 	1 pages in between
#
# j: 0
# j: 1
# j: 2
# j: 0
# j: 1
# j: 2
# 49: https://eng.kuleuven.be/webcms/Shibboleth.sso/Login?target=https://eng.kuleuven.be/archief-hoofdpagina/recover/studenten/deadlines-2014-2015.pdf
#
# 	3: https://eng.kuleuven.be/studenten/programmas/index.html
#
# 	50: https://eng.kuleuven.be/studenten/programmas/index.html
#
# 	1 pages in between
#
# j: 0
# j: 1
# j: 2
# j: 0
# ({'1': 23, '2': 1, '3': 6}, 3.2333333333333334)

# %%
preprocess('u23_1_test_data.csv')
# Out:
# ['http://www.standaard.be/cnt/dmf20160325_02204284',
#  'http://www.standaard.be/plus',
#  'http://www.standaard.be/',
#  'http://www.standaard.be/nieuws/binnenland',
#  'http://www.standaard.be/cnt/dmf20160326_02205525',
#  'http://www.standaard.be/tag/aanslagen-brussel',
#  'http://www.standaard.be/nieuws/buitenland',
#  'http://www.standaard.be/plus/krant/opinie/opinies',
#  'http://www.standaard.be/nieuws/buitenland',
#  'http://www.standaard.be/nieuws/sport',
#  'http://www.standaard.be/nieuws/sport/voetbal',
#  'http://www.standaard.be/nieuws/sport/voetbal?page=2',
#  'http://www.standaard.be/cnt/dmf20160325_02203505',
#  'http://www.standaard.be/plus/ochtend',
#  'http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F4',
#  'http://www.standaard.be/plus/ochtend',
#  'http://www.standaard.be/plus/login?goto=http%3A%2F%2Fwww.standaard.be%3A80%2Fplus%2Fochtend%2F30',
#  'https://search.yahoo.com/yhs/search?p=deredactie&ei=UTF-8&hspart=mozilla&hsimp=yhs-002',
#  'http://deredactie.be/cm/vrtnieuws',
#  'http://deredactie.be/cm/vrtnieuws/videozone',
#  'http://deredactie.be/cm/vrtnieuws/videozone/nieuws/politiek/1.2612587',
#  'http://deredactie.be/cm/vrtnieuws/2.43497/1.2612632?playlist=7.39637',
#  'http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal/2.43555?video=1.2612481',
#  'http://deredactie.be/cm/vrtnieuws/videozone/nieuws/binnenland',
#  'http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal',
#  'http://deredactie.be/cm/vrtnieuws/videozone/meestbekeken',
#  'http://deredactie.be/cm/vrtnieuws/videozone/programmas/journaal/2.43555?video=1.2612492',
#  'http://deredactie.be/cm/vrtnieuws/videozone/nieuws',
#  'http://deredactie.be/cm/vrtnieuws/videozone/livestream',
#  'http://www.kuleuven.be/studenten/',
#  'http://www.kuleuven.be/studenten/starters/index.html',
#  'http://nieuws.kuleuven.be/',
#  'http://nieuws.kuleuven.be/taxonomy/term/59',
#  'http://www.kuleuven.be/kuleuven/',
#  'http://www.kuleuven.be/studeren/',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/#bl=9;&f=-1,-1,-1,-1',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/#bl=9;-1&f=-1,-1,-1,-1',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm',
#  'https://onderwijsaanbod.kuleuven.be/opleidingen/n/F_50000486.htm#bl=all',
#  'http://www.kuleuven.be/wieiswie/nl/person',
#  'https://eng.kuleuven.be/toekomstigestudenten',
#  'https://eng.kuleuven.be/toekomstigestudenten/burgerlijk-ingenieur',
#  'https://eng.kuleuven.be/studenten',
#  'https://eng.kuleuven.be/studenten/programmas/index.html',
#  'https://eng.kuleuven.be/webcms/Shibboleth.sso/Login?target=https://eng.kuleuven.be/archief-hoofdpagina/recover/studenten/deadlines-2014-2015.pdf',
#  'https://eng.kuleuven.be/studenten/programmas/index.html',
#  'https://eng.kuleuven.be/english/education/internationalisation',
#  'https://eng.kuleuven.be/english/education/internationalisation/Erasmus/exchange']
