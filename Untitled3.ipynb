# %%
from model_validator import *
# Out:
# "2016-03-26T17:14:34.430Z",		"load",				 "https://search.yahoo.com/yhs/search?p=deredactie&ei=UTF-8&hspart=mozilla&hsimp=yhs-002", ""
#
# "2016-03-26T17:14:36.968Z",		"click",			 "https://search.yahoo.com/yhs/search?p=deredactie&ei=UTF-8&hspart=mozilla&hsimp=yhs-002", "http://r.search.yahoo.com/_ylt=A86.J755w_ZWfioAJLAnnIlQ;_ylu=X3oDMTByb2lvbXVuBGNvbG8DZ3ExBHBvcwMxBHZ0aWQDBHNlYwNzcg--/RV=2/RE=1459041273/RO=10/RU=http%3a%2f%2fwww.deredactie.be%2f/RK=0/RS=VPslaY9bhttefaE.kK4rMVwHqwA-"
#
# "2016-03-26T17:14:40.718Z",		"load",				 "http://deredactie.be/cm/vrtnieuws", ""
#
# "2016-03-26T17:14:51.617Z",		"click",			 "http://deredactie.be/cm/vrtnieuws", "http://deredactie.be/cm/vrtnieuws#"
#
# "2016-03-26T17:15:02.800Z",		"click",			 "http://deredactie.be/cm/vrtnieuws", "http://deredactie.be/cm/vrtnieuws/videozone"
#
# "2016-03-26T17:15:02.819Z",		"beforeunload",		 "http://deredactie.be/cm/vrtnieuws", ""
#
# ...

# %%
train_and_validate('u23_1_training_data.csv','u23_1_test_data.csv')
# Out:
# "2016-03-26T17:14:34.430Z",		"load",				 "https://search.yahoo.com/yhs/search?p=deredactie&ei=UTF-8&hspart=mozilla&hsimp=yhs-002", ""
#
# "2016-03-26T17:14:36.968Z",		"click",			 "https://search.yahoo.com/yhs/search?p=deredactie&ei=UTF-8&hspart=mozilla&hsimp=yhs-002", "http://r.search.yahoo.com/_ylt=A86.J755w_ZWfioAJLAnnIlQ;_ylu=X3oDMTByb2lvbXVuBGNvbG8DZ3ExBHBvcwMxBHZ0aWQDBHNlYwNzcg--/RV=2/RE=1459041273/RO=10/RU=http%3a%2f%2fwww.deredactie.be%2f/RK=0/RS=VPslaY9bhttefaE.kK4rMVwHqwA-"
#
# "2016-03-26T17:14:40.718Z",		"load",				 "http://deredactie.be/cm/vrtnieuws", ""
#
# "2016-03-26T17:14:51.617Z",		"click",			 "http://deredactie.be/cm/vrtnieuws", "http://deredactie.be/cm/vrtnieuws#"
#
# "2016-03-26T17:15:02.800Z",		"click",			 "http://deredactie.be/cm/vrtnieuws", "http://deredactie.be/cm/vrtnieuws/videozone"
#
# "2016-03-26T17:15:02.819Z",		"beforeunload",		 "http://deredactie.be/cm/vrtnieuws", ""
#
# ...
